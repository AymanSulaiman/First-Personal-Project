# %% [markdown]
# This is my first python visualisation project where I will explore the data for pokemon stats were I compare pokemon, their fighting stats, types, etc.  This is also to show off my python skills.  Here I go.

# %%
#  importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Pokemon.csv', index_col ='Name')

# %%
#  Just seeing the head of the dataframe and seeing what is in the stats
df.head(10)
# Out:
#                            # Type 1  Type 2  Total  HP  Attack  Defense  \
# Name
# Bulbasaur                  1  Grass  Poison    318  45      49       49
# Ivysaur                    2  Grass  Poison    405  60      62       63
# Venusaur                   3  Grass  Poison    525  80      82       83
# VenusaurMega Venusaur      3  Grass  Poison    625  80     100      123
# Charmander                 4   Fire     NaN    309  39      52       43
# Charmeleon                 5   Fire     NaN    405  58      64       58
# Charizard                  6   Fire  Flying    534  78      84       78
# CharizardMega Charizard X  6   Fire  Dragon    634  78     130      111
# CharizardMega Charizard Y  6   Fire  Flying    634  78     104       78
# Squirtle                   7  Water     NaN    314  44      48       65
#
#                            Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# Bulbasaur                       65       65     45           1      False
# ...

# %%
#  I will first make variables relating to generations 1, 2, and 3 as they give me the fondest memories

first_gen = df[df['Generation'] == 1]

second_gen = df[df['Generation'] == 2]

third_gen = df[df['Generation'] == 3]

# %%
#  Now that we have establish the generations, lets compare the speed in each generation

first_gen_speed = first_gen['Speed']
second_gen_speed = second_gen['Speed']
third_gen_speed = third_gen['Speed']


plt.hist(first_gen_speed, color = 'Green')
plt.axvline(first_gen_speed.mean(), color='k', linestyle='dashed', linewidth=3)

plt.title('Gens 1 Speed histogram and mean line')
plt.xlabel('Speed Unit')
plt.ylabel('Count')

plt.show()

plt.hist(second_gen_speed, color = 'Red')
plt.axvline(second_gen_speed.mean(), color='k', linestyle='dashed', linewidth=3)

plt.title('Gens 2 Speed histogram and mean line')
plt.xlabel('Speed Unit')
plt.ylabel('Count')

plt.show()

plt.hist(third_gen_speed, color = 'Blue')
plt.axvline(third_gen_speed.mean(), color='k', linestyle='dashed', linewidth=3)

plt.title('Gens 3 Speed histogram and mean line')
plt.xlabel('Speed Unit')
plt.ylabel('Count')

plt.show()

#  We can see that Gen 1 has the highest mean for the speed and the Gen 3 speed stats have a larger range
#  and Gen 2 has the worst of both worlds.

# %%
#  Now I want to explore the stas of each fire type starter pokemon final evolution since they are lit as hell

Charizard = first_gen.loc['Charizard']                      
Typhlosion = second_gen.loc['Typhlosion']
Blaziken = third_gen.loc['Blaziken']

'''
print('------------------------------')
print(Charizard)
print('------------------------------')
print(Typhlosion)
print('------------------------------')
print(Blaziken)
print('------------------------------')
This was to check if I got everything right
'''

#  I want to compare the stats of each pokemon selected on a single radar chart and I will import seaborn as sns
#  and learn this technique from kaggle.com [https://www.kaggle.com/typewind/draw-a-radar-chart-with-python-in-a-simple-way]

'''
import seaborn as sns

labels=np.array(['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed'])
angles=np.linspace(0, 2*np.pi, len(labels), endpoint=False)
# close the plot
#stats=np.concatenate((stats,[stats[0]]))
angles=np.concatenate((angles,[angles[0]]))
fig=sns.plt.figure()
ax = fig.add_subplot(111, polar=True)
ax.plot(angles, stats, 'o-', linewidth=2)
ax.fill(angles, stats, alpha=0.25)
ax.set_thetagrids(angles * 180/np.pi, labels)
#ax.set_title([df.loc[386,"Name"]])
ax.grid(True)
'''


#  Work in progress
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-e40128869f5f> in <module>
#      26 #stats=np.concatenate((stats,[stats[0]]))
#      27 angles=np.concatenate((angles,[angles[0]]))
# ---> 28 fig=sns.plt.figure()
#      29 ax = fig.add_subplot(111, polar=True)
#      30 ax.plot(angles, stats, 'o-', linewidth=2)
#
# AttributeError: module 'seaborn' has no attribute 'plt'
